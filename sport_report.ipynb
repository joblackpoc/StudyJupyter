# %%
import urllib
import pandas as pd
url = 'https://docs.google.com/spreadsheets/d/15mbP43zUfy_xr3lGbYFPdwW6PnolZHYpbKbuScV-H9c/export?gid=1127047774&format=csv'
df2 = pd.read_csv(url)
from pivottablejs import pivot_ui
pivot_ui(df2,width=1600)
# Out:
#         <iframe
#             width="1600"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
import pandas as pd
import urllib
url = 'https://docs.google.com/spreadsheets/d/15mbP43zUfy_xr3lGbYFPdwW6PnolZHYpbKbuScV-H9c/export?gid=1127047774&format=csv'
df = pd.read_csv(url)
df
# Out:
#               ประทับเวลา วันที่รายงาน                  ชื่อ_นามสกุล  \
# 0    19/10/2018, 9:36:26   19/10/2018               ดญ.แพรวา จงจิตร
# 1    19/10/2018, 9:45:05   19/10/2018          นายณัฏฐพัชร์ สุขเกษม
# 2   19/10/2018, 11:23:52   19/10/2018               ธัญรดา โทธรัตน์
# 3   19/10/2018, 12:03:35   19/10/2018            ดช.นัชนัน ชีวะโรรส
# 4   19/10/2018, 13:35:41   19/10/2018               กัญญธมล ยอดสนิท
# 5   19/10/2018, 13:57:25   19/10/2018           จอมขวัญ เวทยไวกูณฐ์
# 6   20/10/2018, 11:31:37   20/10/2018                 นิชกรณ์ จิตรา
# 7    20/10/2018, 9:58:11   20/10/2018               ศุภสัณห์ นิยมรส
# 8   20/10/2018, 11:39:56   20/10/2018              ณัฎฐพัชร สุขเกษม
# 9   20/10/2018, 11:42:29   20/10/2018                  แพรวา จงจิตร
# 10  20/10/2018, 12:29:32   20/10/2018             นายณัฐยศ ยิ่งยงค์
# 11  20/10/2018, 13:22:52   20/10/2018            มะนูเส็ง เดิมดอล่า
# 12  20/10/2018, 13:28:00   20/10/2018          จอมขวัญ เวทย์ไวคูณฐ์
# ...

# %%
df.shape
# Out:
# (69, 26)

# %%
rows, columns = df.shape

# %%
rows
# Out:
# 69

# %%
columns
# Out:
# 26

# %%
df.head()
# Out:
#              ประทับเวลา วันที่รายงาน          ชื่อ_นามสกุล  \
# 0   19/10/2018, 9:36:26   19/10/2018       ดญ.แพรวา จงจิตร
# 1   19/10/2018, 9:45:05   19/10/2018  นายณัฏฐพัชร์ สุขเกษม
# 2  19/10/2018, 11:23:52   19/10/2018       ธัญรดา โทธรัตน์
# 3  19/10/2018, 12:03:35   19/10/2018    ดช.นัชนัน ชีวะโรรส
# 4  19/10/2018, 13:35:41   19/10/2018       กัญญธมล ยอดสนิท
#
#    เลขประจำตัวประชาชน   เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  \
# 0        1.930800e+12  หญิง    14       619841485             สงขลา
# 1        1.720400e+12   ชาย    32       957391565              กทม.
# 2        1.839901e+12  หญิง    16       639396292            ภูเก็ต
# 3        1.849902e+12   ชาย    13      8694711119            สุราษฯ
# 4        1.809902e+12  หญิง    14       945898239     นครศรีธรรมราช
#
#                   ตำแหน่ง ประเภทกีฬา            ...              \
# 0                 นักกีฬา     เทนนิส            ...
# 1  ผู้ฝึกสอน/ผู้จัดการทีม     เทนนิส            ...
# ...

# %%
df.tail()
# Out:
#               ประทับเวลา วันที่รายงาน            ชื่อ_นามสกุล  \
# 64  23/10/2018, 16:52:18   23/10/2018  นางสาวฟารีดา เหล็มเต๊ะ
# 65  23/10/2018, 22:56:46   23/10/2018   นายพิสิษสรรค์ วีระกิต
# 66   24/10/2018, 9:53:38   24/10/2018     นายศุภรัตน์ นิธิมรร
# 67  24/10/2018, 10:00:49   24/10/2018            เมษา สุราวุธ
# 68  24/10/2018, 10:23:26   24/10/2018      ด.ญ.อรอนงค์. สีตอง
#
#     เลขประจำตัวประชาชน   เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  \
# 64        1.919900e+12  หญิง    18       610396854             สงขลา
# 65        1.839902e+12   ชาย    15       887570782            ภูเก็ต
# 66        3.800901e+12   ชาย    62       918256917             ชุมพร
# 67        1.819900e+12   ชาย    14       622199727             สงขลา
# 68        1.929901e+12  หญิง    16       979734094              ตรัง
#
#             ตำแหน่ง      ประเภทกีฬา             ...               \
# 64          นักกีฬา  แฮนด์บอลชายหาด             ...
# 65          นักกีฬา         จักรยาน             ...
# ...

# %%
df.tail(1)
# Out:
#               ประทับเวลา วันที่รายงาน        ชื่อ_นามสกุล  เลขประจำตัวประชาชน  \
# 68  24/10/2018, 10:23:26   24/10/2018  ด.ญ.อรอนงค์. สีตอง        1.929901e+12
#
#      เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  ตำแหน่ง  ประเภทกีฬา  \
# 68  หญิง    16       979734094              ตรัง  นักกีฬา  ฟุตบอลหญิง
#
#            ...          วินิจฉัย.1 กลุ่มการบาดเจ็บ ตำแหน่งที่ได้รับบาดเจ็บ  \
# 68         ...           Cotussion      Contussion                   ศีรษะ
#
#    อวัยวะที่ได้รับบาดเจ็บ การรักษา (วิธีการรักษา/ยาที่ให้/ขนาดยา)  \
# 68                  ศีรษะ                  ประคบเย็น paracetamol
#
#    ประการส่งตัว กรณีส่งต่อระบุโรงพยาบาล Triage Score  \
# 68     กลับบ้าน                     NaN        เขียว
#
#    สถานที่แข่งขัน/ที่พัก/หน่วยบริการ         ที่อยู่อีเมล
# 68                   วิทยาลัพละชุมพร  aim_aem@hotmail.com
#
# [1 rows x 26 columns]

# %%
df[2:5]
# Out:
#              ประทับเวลา วันที่รายงาน        ชื่อ_นามสกุล  เลขประจำตัวประชาชน  \
# 2  19/10/2018, 11:23:52   19/10/2018     ธัญรดา โทธรัตน์        1.839901e+12
# 3  19/10/2018, 12:03:35   19/10/2018  ดช.นัชนัน ชีวะโรรส        1.849902e+12
# 4  19/10/2018, 13:35:41   19/10/2018     กัญญธมล ยอดสนิท        1.809902e+12
#
#     เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  ตำแหน่ง ประเภทกีฬา  \
# 2  หญิง    16       639396292            ภูเก็ต  นักกีฬา     เทนนิส
# 3   ชาย    13      8694711119            สุราษฯ  นักกีฬา     เทนนิส
# 4  หญิง    14       945898239     นครศรีธรรมราช  นักกีฬา     เทนนิส
#
#              ...                 วินิจฉัย.1            กลุ่มการบาดเจ็บ  \
# 2            ...              Muscle strain  Injury to Muscle & Tendon
# 3            ...              Muscle strain  Injury to Muscle & Tendon
# 4            ...              Muscle strain  Injury to Muscle & Tendon
#
#   ตำแหน่งที่ได้รับบาดเจ็บ อวัยวะที่ได้รับบาดเจ็บ  \
# ...

# %%
df.columns
# Out:
# Index(['ประทับเวลา', 'วันที่รายงาน', 'ชื่อ_นามสกุล', 'เลขประจำตัวประชาชน',
#        'เพศ', 'อายุ', 'หมายเลขโทรศัพท์', 'เป็นตัวแทนจังหวัด', 'ตำแหน่ง',
#        'ประเภทกีฬา', 'ประเภทของการป่วย', 'อาการ/อาการแสดงระบุ', 'วินิจฉัย',
#        'กลุ่ม กรณีป่วย', 'การบาดเจ็บเกิดขึ้น', 'อาการและอาการแสดง',
#        'วินิจฉัย.1', 'กลุ่มการบาดเจ็บ', 'ตำแหน่งที่ได้รับบาดเจ็บ',
#        'อวัยวะที่ได้รับบาดเจ็บ', 'การรักษา (วิธีการรักษา/ยาที่ให้/ขนาดยา)',
#        'ประการส่งตัว', 'กรณีส่งต่อระบุโรงพยาบาล', 'Triage Score',
#        'สถานที่แข่งขัน/ที่พัก/หน่วยบริการ', 'ที่อยู่อีเมล'],
#       dtype='object')

# %%
df['ตำแหน่ง']
# Out:
# 0                    นักกีฬา
# 1     ผู้ฝึกสอน/ผู้จัดการทีม
# 2                    นักกีฬา
# 3                    นักกีฬา
# 4                    นักกีฬา
# 5                    นักกีฬา
# 6                    กรรมการ
# 7                    กรรมการ
# 8            กรรมการส่วนกลาง
# 9                    นักกีฬา
# 10                   นักกีฬา
# 11           กรรมการส่วนกลาง
# 12                   นักกีฬา
# 13                   นักกีฬา
# 14                   นักกีฬา
# 15                   นักกีฬา
# 16                   นักกีฬา
# 17                   นักกีฬา
# 18                   นักกีฬา
# 19                   นักกีฬา
# 20                   นักกีฬา
# 21    ผู้ฝึกสอน/ผู้จัดการทีม
# 22                   นักกีฬา
# 23           คนเก็บลูกเทนนิส
# 24                   นักกีฬา
# 25                   กรรมการ
# 26                   นักกีฬา
# 27                       NaN
# 28                   นักกีฬา
# 29                   นักกีฬา
#                ...
# 39                   นักกีฬา
# ...

# %%
df[['ประเภทกีฬา','วินิจฉัย','เพศ']]
# Out:
#           ประเภทกีฬา            วินิจฉัย   เพศ
# 0             เทนนิส      ทำแผลต่อเนื่อง  หญิง
# 1             เทนนิส                 ไข้   ชาย
# 2             เทนนิส       Muscle strain  หญิง
# 3             เทนนิส       Muscle strain   ชาย
# 4             เทนนิส       Muscle strain  หญิง
# 5             เทนนิส           Epistaxis  หญิง
# 6             เทนนิส           Urticaria   ชาย
# 7             เทนนิส                 NaN   ชาย
# 8             เทนนิส            Diarrhea   ชาย
# 9             เทนนิส                 NaN  หญิง
# 10           ยูยิตสู       muscle strain   ชาย
# 11            เทนนิส                 URI   ชาย
# 12            เทนนิส                 NaN  หญิง
# 13            เทนนิส            Headache   ชาย
# 14            เทนนิส       Muscle strain  หญิง
# 15            เทนนิส                 NaN  หญิง
# 16            เทนนิส                 NaN  หญิง
# 17         ฟุตบอลชาย        muscle stain   ชาย
# 18           เทนเนิส                 NaN   ชาย
# ...

# %%
df['วันที่รายงาน'].max()
# Out:
# '24/10/2018'

# %%
df['อายุ'].mean()
# Out:
# 21.985507246376812

# %%
df['อายุ'].max()
# Out:
# 62

# %%
df['อายุ'].min()
# Out:
# 13

# %%
df['อายุ'].std()
# Out:
# 14.131205303931385

# %%
df.describe()
# Out:
#        เลขประจำตัวประชาชน       อายุ
# count        6.100000e+01  69.000000
# mean         2.125778e+12  21.985507
# std          7.881080e+11  14.131205
# min          1.103704e+12  13.000000
# 25%          1.809902e+12  14.000000
# 50%          1.849902e+12  16.000000
# 75%          1.930800e+12  18.000000
# max          3.969900e+12  62.000000

# %%
df[df.อายุ>=40]
# Out:
#               ประทับเวลา วันที่รายงาน                ชื่อ_นามสกุล  \
# 7    20/10/2018, 9:58:11   20/10/2018             ศุภสัณห์ นิยมรส
# 20  20/10/2018, 17:03:40   20/10/2018      นายกิตติพงศ์  เกื้อแสง
# 21  20/10/2018, 17:30:08   20/10/2018     นายกิตติพงศ์  เกื้อแสง
# 41  21/10/2018, 18:42:09   21/10/2018            นายอาคม อนันตกูล
# 42  21/10/2018, 18:45:51   21/10/2018          นางสุภาวิตา เภามณี
# 43  21/10/2018, 18:52:47   21/10/2018           จสอ.มานพ สาราษฎร์
# 46  22/10/2018, 10:58:37   22/10/2018       นายวุฒิชัย พิชัยยุทธ์
# 48  22/10/2018, 12:19:05   22/10/2018            นายอาคม อนันตกูล
# 59   23/10/2018, 9:06:52   23/10/2018  นายวิเชียร  พู่พงค์ไพบูลย์
# 66   24/10/2018, 9:53:38   24/10/2018         นายศุภรัตน์ นิธิมรร
#
#     เลขประจำตัวประชาชน   เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  \
# 7         3.800901e+12   ชาย    62       915256917     นครศรีธรรมราช
# 20        3.915001e+12   ชาย    47     095-0207790            ภูเก็ต
# ...

# %%
df[df.อายุ==df.อายุ.max()]
# Out:
#               ประทับเวลา วันที่รายงาน         ชื่อ_นามสกุล  \
# 7    20/10/2018, 9:58:11   20/10/2018      ศุภสัณห์ นิยมรส
# 41  21/10/2018, 18:42:09   21/10/2018     นายอาคม อนันตกูล
# 48  22/10/2018, 12:19:05   22/10/2018     นายอาคม อนันตกูล
# 66   24/10/2018, 9:53:38   24/10/2018  นายศุภรัตน์ นิธิมรร
#
#     เลขประจำตัวประชาชน  เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  \
# 7         3.800901e+12  ชาย    62       915256917     นครศรีธรรมราช
# 41        3.969900e+12  ชาย    62       954302629               NaN
# 48        3.969900e+12  ชาย    62       954302629             สงขลา
# 66        3.800901e+12  ชาย    62       918256917             ชุมพร
#
#             ตำแหน่ง ประเภทกีฬา             ...                   วินิจฉัย.1  \
# 7           กรรมการ     เทนนิส             ...                          NaN
# 41          กรรมการ     เทนนิส             ...                          NaN
# 48          กรรมการ  ซอฟเทนนิส             ...               Muscle strain
# ...

# %%
df[df.อายุ==df['อายุ'].max()]
# Out:
#               ประทับเวลา วันที่รายงาน         ชื่อ_นามสกุล  \
# 7    20/10/2018, 9:58:11   20/10/2018      ศุภสัณห์ นิยมรส
# 41  21/10/2018, 18:42:09   21/10/2018     นายอาคม อนันตกูล
# 48  22/10/2018, 12:19:05   22/10/2018     นายอาคม อนันตกูล
# 66   24/10/2018, 9:53:38   24/10/2018  นายศุภรัตน์ นิธิมรร
#
#     เลขประจำตัวประชาชน  เพศ  อายุ หมายเลขโทรศัพท์ เป็นตัวแทนจังหวัด  \
# 7         3.800901e+12  ชาย    62       915256917     นครศรีธรรมราช
# 41        3.969900e+12  ชาย    62       954302629               NaN
# 48        3.969900e+12  ชาย    62       954302629             สงขลา
# 66        3.800901e+12  ชาย    62       918256917             ชุมพร
#
#             ตำแหน่ง ประเภทกีฬา             ...                   วินิจฉัย.1  \
# 7           กรรมการ     เทนนิส             ...                          NaN
# 41          กรรมการ     เทนนิส             ...                          NaN
# 48          กรรมการ  ซอฟเทนนิส             ...               Muscle strain
# ...

# %%
df['ประทับเวลา'][df.อายุ==df['อายุ'].max()]
# Out:
# 7      20/10/2018, 9:58:11
# 41    21/10/2018, 18:42:09
# 48    22/10/2018, 12:19:05
# 66     24/10/2018, 9:53:38
# Name: ประทับเวลา, dtype: object

# %%
df[['วันที่รายงาน','อายุ']][df.อายุ==df['อายุ'].max()]
# Out:
#    วันที่รายงาน  อายุ
# 7    20/10/2018    62
# 41   21/10/2018    62
# 48   22/10/2018    62
# 66   24/10/2018    62

# %%
df.index
# Out:
# RangeIndex(start=0, stop=69, step=1)

# %%
df.set_index('วันที่รายงาน')
# Out:
#                         ประทับเวลา                  ชื่อ_นามสกุล  \
# วันที่รายงาน
# 19/10/2018     19/10/2018, 9:36:26               ดญ.แพรวา จงจิตร
# 19/10/2018     19/10/2018, 9:45:05          นายณัฏฐพัชร์ สุขเกษม
# 19/10/2018    19/10/2018, 11:23:52               ธัญรดา โทธรัตน์
# 19/10/2018    19/10/2018, 12:03:35            ดช.นัชนัน ชีวะโรรส
# 19/10/2018    19/10/2018, 13:35:41               กัญญธมล ยอดสนิท
# 19/10/2018    19/10/2018, 13:57:25           จอมขวัญ เวทยไวกูณฐ์
# 20/10/2018    20/10/2018, 11:31:37                 นิชกรณ์ จิตรา
# 20/10/2018     20/10/2018, 9:58:11               ศุภสัณห์ นิยมรส
# 20/10/2018    20/10/2018, 11:39:56              ณัฎฐพัชร สุขเกษม
# 20/10/2018    20/10/2018, 11:42:29                  แพรวา จงจิตร
# 20/10/2018    20/10/2018, 12:29:32             นายณัฐยศ ยิ่งยงค์
# 20/10/2018    20/10/2018, 13:22:52            มะนูเส็ง เดิมดอล่า
# 20/10/2018    20/10/2018, 13:28:00          จอมขวัญ เวทย์ไวคูณฐ์
# ...

# %%
df
# Out:
#               ประทับเวลา วันที่รายงาน                  ชื่อ_นามสกุล  \
# 0    19/10/2018, 9:36:26   19/10/2018               ดญ.แพรวา จงจิตร
# 1    19/10/2018, 9:45:05   19/10/2018          นายณัฏฐพัชร์ สุขเกษม
# 2   19/10/2018, 11:23:52   19/10/2018               ธัญรดา โทธรัตน์
# 3   19/10/2018, 12:03:35   19/10/2018            ดช.นัชนัน ชีวะโรรส
# 4   19/10/2018, 13:35:41   19/10/2018               กัญญธมล ยอดสนิท
# 5   19/10/2018, 13:57:25   19/10/2018           จอมขวัญ เวทยไวกูณฐ์
# 6   20/10/2018, 11:31:37   20/10/2018                 นิชกรณ์ จิตรา
# 7    20/10/2018, 9:58:11   20/10/2018               ศุภสัณห์ นิยมรส
# 8   20/10/2018, 11:39:56   20/10/2018              ณัฎฐพัชร สุขเกษม
# 9   20/10/2018, 11:42:29   20/10/2018                  แพรวา จงจิตร
# 10  20/10/2018, 12:29:32   20/10/2018             นายณัฐยศ ยิ่งยงค์
# 11  20/10/2018, 13:22:52   20/10/2018            มะนูเส็ง เดิมดอล่า
# 12  20/10/2018, 13:28:00   20/10/2018          จอมขวัญ เวทย์ไวคูณฐ์
# ...

# %%
df.set_index('วันที่รายงาน', inplace=True)

# %%
df
# Out:
#                         ประทับเวลา                  ชื่อ_นามสกุล  \
# วันที่รายงาน
# 19/10/2018     19/10/2018, 9:36:26               ดญ.แพรวา จงจิตร
# 19/10/2018     19/10/2018, 9:45:05          นายณัฏฐพัชร์ สุขเกษม
# 19/10/2018    19/10/2018, 11:23:52               ธัญรดา โทธรัตน์
# 19/10/2018    19/10/2018, 12:03:35            ดช.นัชนัน ชีวะโรรส
# 19/10/2018    19/10/2018, 13:35:41               กัญญธมล ยอดสนิท
# 19/10/2018    19/10/2018, 13:57:25           จอมขวัญ เวทยไวกูณฐ์
# 20/10/2018    20/10/2018, 11:31:37                 นิชกรณ์ จิตรา
# 20/10/2018     20/10/2018, 9:58:11               ศุภสัณห์ นิยมรส
# 20/10/2018    20/10/2018, 11:39:56              ณัฎฐพัชร สุขเกษม
# 20/10/2018    20/10/2018, 11:42:29                  แพรวา จงจิตร
# 20/10/2018    20/10/2018, 12:29:32             นายณัฐยศ ยิ่งยงค์
# 20/10/2018    20/10/2018, 13:22:52            มะนูเส็ง เดิมดอล่า
# 20/10/2018    20/10/2018, 13:28:00          จอมขวัญ เวทย์ไวคูณฐ์
# ...

# %%
df.loc['23/10/2018']
# Out:
#                         ประทับเวลา                ชื่อ_นามสกุล  \
# วันที่รายงาน
# 23/10/2018     23/10/2018, 9:06:52  นายวิเชียร  พู่พงค์ไพบูลย์
# 23/10/2018    23/10/2018, 10:08:24            ดญ.แพรวา  จงจิตร
# 23/10/2018    23/10/2018, 10:19:30        จอมขวัญ  เวทยไวกูณฐ์
# 23/10/2018    23/10/2018, 13:17:21        นส.ปิยมน  พิชัยยุทธ์
# 23/10/2018    23/10/2018, 16:50:01           ธนาดร สุวรรณกานต์
# 23/10/2018    23/10/2018, 16:52:18      นางสาวฟารีดา เหล็มเต๊ะ
# 23/10/2018    23/10/2018, 22:56:46       นายพิสิษสรรค์ วีระกิต
#
#               เลขประจำตัวประชาชน   เพศ  อายุ หมายเลขโทรศัพท์  \
# วันที่รายงาน
# 23/10/2018          3.950600e+12   ชาย    61       993574638
# 23/10/2018          1.930800e+12  หญิง    14       917307100
# 23/10/2018          1.103704e+12  หญิง    13       818912109
# 23/10/2018          1.900101e+12  หญิง    16       945955122
# 23/10/2018                   NaN   ชาย    17             NaN
# 23/10/2018          1.919900e+12  หญิง    18       610396854
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    วันที่รายงาน            ประทับเวลา                  ชื่อ_นามสกุล  \
# 0    19/10/2018   19/10/2018, 9:36:26               ดญ.แพรวา จงจิตร
# 1    19/10/2018   19/10/2018, 9:45:05          นายณัฏฐพัชร์ สุขเกษม
# 2    19/10/2018  19/10/2018, 11:23:52               ธัญรดา โทธรัตน์
# 3    19/10/2018  19/10/2018, 12:03:35            ดช.นัชนัน ชีวะโรรส
# 4    19/10/2018  19/10/2018, 13:35:41               กัญญธมล ยอดสนิท
# 5    19/10/2018  19/10/2018, 13:57:25           จอมขวัญ เวทยไวกูณฐ์
# 6    20/10/2018  20/10/2018, 11:31:37                 นิชกรณ์ จิตรา
# 7    20/10/2018   20/10/2018, 9:58:11               ศุภสัณห์ นิยมรส
# 8    20/10/2018  20/10/2018, 11:39:56              ณัฎฐพัชร สุขเกษม
# 9    20/10/2018  20/10/2018, 11:42:29                  แพรวา จงจิตร
# 10   20/10/2018  20/10/2018, 12:29:32             นายณัฐยศ ยิ่งยงค์
# 11   20/10/2018  20/10/2018, 13:22:52            มะนูเส็ง เดิมดอล่า
# 12   20/10/2018  20/10/2018, 13:28:00          จอมขวัญ เวทย์ไวคูณฐ์
# ...

# %%
df.set_index('เพศ',inplace=True)

# %%
df
# Out:
#                 ประทับเวลา                  ชื่อ_นามสกุล  เลขประจำตัวประชาชน  \
# เพศ
# หญิง   19/10/2018, 9:36:26               ดญ.แพรวา จงจิตร        1.930800e+12
# ชาย    19/10/2018, 9:45:05          นายณัฏฐพัชร์ สุขเกษม        1.720400e+12
# หญิง  19/10/2018, 11:23:52               ธัญรดา โทธรัตน์        1.839901e+12
# ชาย   19/10/2018, 12:03:35            ดช.นัชนัน ชีวะโรรส        1.849902e+12
# หญิง  19/10/2018, 13:35:41               กัญญธมล ยอดสนิท        1.809902e+12
# หญิง  19/10/2018, 13:57:25           จอมขวัญ เวทยไวกูณฐ์        1.103704e+12
# ชาย   20/10/2018, 11:31:37                 นิชกรณ์ จิตรา        1.840100e+12
# ชาย    20/10/2018, 9:58:11               ศุภสัณห์ นิยมรส        3.800901e+12
# ชาย   20/10/2018, 11:39:56              ณัฎฐพัชร สุขเกษม        1.720400e+12
# หญิง  20/10/2018, 11:42:29                  แพรวา จงจิตร        1.930800e+12
# ชาย   20/10/2018, 12:29:32             นายณัฐยศ ยิ่งยงค์                 NaN
# ...

# %%
df.loc['ชาย']
# Out:
#                ประทับเวลา                ชื่อ_นามสกุล  เลขประจำตัวประชาชน  \
# เพศ
# ชาย   19/10/2018, 9:45:05        นายณัฏฐพัชร์ สุขเกษม        1.720400e+12
# ชาย  19/10/2018, 12:03:35          ดช.นัชนัน ชีวะโรรส        1.849902e+12
# ชาย  20/10/2018, 11:31:37               นิชกรณ์ จิตรา        1.840100e+12
# ชาย   20/10/2018, 9:58:11             ศุภสัณห์ นิยมรส        3.800901e+12
# ชาย  20/10/2018, 11:39:56            ณัฎฐพัชร สุขเกษม        1.720400e+12
# ชาย  20/10/2018, 12:29:32           นายณัฐยศ ยิ่งยงค์                 NaN
# ชาย  20/10/2018, 13:22:52          มะนูเส็ง เดิมดอล่า        1.900600e+12
# ชาย  20/10/2018, 13:31:55             นันทนะ ชีวะโรรส                 NaN
# ชาย  20/10/2018, 17:12:23          นายนาซี หมัดอะดั้ม        1.909803e+12
# ชาย  20/10/2018, 16:25:52             นฐกิต จินดาเพชร        1.809902e+12
# ชาย  20/10/2018, 16:30:56            ภูมิ ปิยะปานันท์        1.839901e+12
# ชาย  20/10/2018, 17:03:40      นายกิตติพงศ์  เกื้อแสง        3.915001e+12
# ...
