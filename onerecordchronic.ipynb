# %%
import pandas as pd
df = pd.read_csv("data/onerecordchronic.csv")
df.head()
# Out:
#         OID  HOSPCODE  YEAR_RPT  AGE     SEX IS_HT_NON_REGISTER IS_HT  \
# 0  20736993      9406      2555   23    male                  N     N
# 1  20736994      9383      2555    6    male                  N     N
# 2  20736995      9406      2555   35    male                  N     N
# 3  20736996      9406      2555   21  female                  N     N
# 4  20736997      9406      2555   38    male                  N     N
#
#   IS_HT_FIRST  HT_SBP  HT_DBP      ...       HT_COM_HEART HT_COM_BRAIN  \
# 0           N       0       0      ...                NaN          NaN
# 1           N       0       0      ...                NaN          NaN
# 2           N       0       0      ...                NaN          NaN
# 3           N       0       0      ...                NaN          NaN
# 4           N       0       0      ...                NaN          NaN
#
#   HT_COM_FOOT HT_COM_OTHER  DM_COM_EYE  DM_COM_KIDNEY  DM_COM_HEART  \
# ...

# %%
import pandas as pd
df = pd.read_csv("data/onerecordchronic.csv")
from pivottablejs import pivot_ui
pivot_ui(df)
# Out:
#         <iframe
#             width="100%"
#             height="500"
#             src="pivottablejs.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
