# %%
name = input("Enter your name : ")
print ("Hello", name)
# Out:
# Enter your name : poc
# Hello poc

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([3,10,2,8,4])
plt.show()
